# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('DataSets/flight_price.xlsx')

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
df['Date'] = df['Date_of_Journey'].str.split('/').str[0]
df['Month'] = df["Date_of_Journey"].str.split('/').str[1]
df['Year'] = df['Date_of_Journey'].str.split('/').str[2]

# %%
df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price Date  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897   24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662    1
#
#   Month  Year
# 0    03  2019
# 1    05  2019

# %%
df['Date'] = df['Date'].astype(int)
df['Month'] = df['Month'].astype(int)
df['Year'] = df['Year'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
#  11  Date             10683 non-null  int64
#  12  Month            10683 non-null  int64
#  13  Year             10683 non-null  int64
# dtypes: int64(4), object(10)
# memory usage: 1.1+ MB

# %%
df.drop('Date_of_Journey', axis = 1, inplace = True)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price  Date  Month  Year
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897    24      3  2019
# 1         13:15   7h 25m     2 stops         No info   7662     1      5  2019
# 2  04:25 10 Jun      19h     2 stops         No info  13882     9      6  2019
# 3         23:30   5h 25m      1 stop         No info   6218    12      5  2019
# 4         21:35   4h 45m      1 stop         No info  13302     1      3  2019

# %%
df['Arrival_Time'].str.split(' ').str[0]
# Out:
# 0        01:10
# 1        13:15
# 2        04:25
# 3        23:30
# 4        21:35
#          ...
# 10678    22:25
# 10679    23:20
# 10680    11:20
# 10681    14:10
# 10682    19:15
# Name: Arrival_Time, Length: 10683, dtype: object

# %%
df['Arrival_Time'] = df['Arrival_Time'].str.split(' ').str[0]

# %%
df['Arrival_Hour'] = df['Arrival_Time'].str.split(':').str[0]
df['Arrival_Min'] = df['Arrival_Time'].str.split(':').str[1]

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info  Price  Date  Month  Year  \
# 0        01:10   2h 50m    non-stop         No info   3897    24      3  2019
# 1        13:15   7h 25m     2 stops         No info   7662     1      5  2019
# 2        04:25      19h     2 stops         No info  13882     9      6  2019
# 3        23:30   5h 25m      1 stop         No info   6218    12      5  2019
# 4        21:35   4h 45m      1 stop         No info  13302     1      3  2019
#
#   Arrival_Hour Arrival_Min
# 0           01          10
# 1           13          15
# 2           04          25
# 3           23          30
# 4           21          35

# %%
df['Arrival_Hour'] = df['Arrival_Hour'].astype(int)
df['Arrival_Min'] = df['Arrival_Min'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Source           10683 non-null  object
#  2   Destination      10683 non-null  object
#  3   Route            10682 non-null  object
#  4   Dep_Time         10683 non-null  object
#  5   Arrival_Time     10683 non-null  object
#  6   Duration         10683 non-null  object
#  7   Total_Stops      10682 non-null  object
#  8   Additional_Info  10683 non-null  object
#  9   Price            10683 non-null  int64
#  10  Date             10683 non-null  int64
#  11  Month            10683 non-null  int64
#  12  Year             10683 non-null  int64
#  13  Arrival_Hour     10683 non-null  int64
#  14  Arrival_Min      10683 non-null  int64
# dtypes: int64(6), object(9)
# memory usage: 1.2+ MB

# %%
df.drop(['Arrival_Time'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50   4h 45m
#
#   Total_Stops Additional_Info  Price  Date  Month  Year  Arrival_Hour  \
# 0    non-stop         No info   3897    24      3  2019             1
# 1     2 stops         No info   7662     1      5  2019            13
# 2     2 stops         No info  13882     9      6  2019             4
# 3      1 stop         No info   6218    12      5  2019            23
# 4      1 stop         No info  13302     1      3  2019            21
#
#    Arrival_Min
# 0           10
# 1           15
# 2           25
# 3           30
# 4           35

# %%
df.drop(['Route'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#        Airline    Source Destination Dep_Time Duration Total_Stops  \
# 0       IndiGo  Banglore   New Delhi    22:20   2h 50m    non-stop
# 1    Air India   Kolkata    Banglore    05:50   7h 25m     2 stops
# 2  Jet Airways     Delhi      Cochin    09:25      19h     2 stops
# 3       IndiGo   Kolkata    Banglore    18:05   5h 25m      1 stop
# 4       IndiGo  Banglore   New Delhi    16:50   4h 45m      1 stop
#
#   Additional_Info  Price  Date  Month  Year  Arrival_Hour  Arrival_Min
# 0         No info   3897    24      3  2019             1           10
# 1         No info   7662     1      5  2019            13           15
# 2         No info  13882     9      6  2019             4           25
# 3         No info   6218    12      5  2019            23           30
# 4         No info  13302     1      3  2019            21           35

# %%
df['Dep_Hour'] = df['Dep_Time'].str.split(':').str[0]
df['Dep_Min'] = df['Dep_Time'].str.split(':').str[1]

# %%
df.head()
# Out:
#        Airline    Source Destination Dep_Time Duration Total_Stops  \
# 0       IndiGo  Banglore   New Delhi    22:20   2h 50m    non-stop
# 1    Air India   Kolkata    Banglore    05:50   7h 25m     2 stops
# 2  Jet Airways     Delhi      Cochin    09:25      19h     2 stops
# 3       IndiGo   Kolkata    Banglore    18:05   5h 25m      1 stop
# 4       IndiGo  Banglore   New Delhi    16:50   4h 45m      1 stop
#
#   Additional_Info  Price  Date  Month  Year  Arrival_Hour  Arrival_Min  \
# 0         No info   3897    24      3  2019             1           10
# 1         No info   7662     1      5  2019            13           15
# 2         No info  13882     9      6  2019             4           25
# 3         No info   6218    12      5  2019            23           30
# 4         No info  13302     1      3  2019            21           35
#
#   Dep_Hour Dep_Min
# 0       22      20
# 1       05      50
# 2       09      25
# 3       18      05
# 4       16      50

# %%
df['Dep_Hour'] = df['Dep_Hour'].astype(int)
df['Dep_Min'] = df['Dep_Min'].astype(int)

# %%
df.drop(['Dep_Time'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#        Airline    Source Destination Duration Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m    non-stop         No info
# 1    Air India   Kolkata    Banglore   7h 25m     2 stops         No info
# 2  Jet Airways     Delhi      Cochin      19h     2 stops         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m      1 stop         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m      1 stop         No info
#
#    Price  Date  Month  Year  Arrival_Hour  Arrival_Min  Dep_Hour  Dep_Min
# 0   3897    24      3  2019             1           10        22       20
# 1   7662     1      5  2019            13           15         5       50
# 2  13882     9      6  2019             4           25         9       25
# 3   6218    12      5  2019            23           30        18        5
# 4  13302     1      3  2019            21           35        16       50

# %%
df['Duration_Hour'] = df['Duration'].str.split(' ').str[0].str.split('h').str[0]

# %%
df['Duration_Min'] = df['Duration'].str.split(' ').str[1].str.split('m').str[0]

# %%
df['Duration_Min'] = df["Duration_Min"].fillna(0)

# %%
df['Duration_Min'].isnull().sum()
# Out:
# 0

# %%
df.head(50)
# Out:
#               Airline    Source Destination Duration Total_Stops  \
# 0              IndiGo  Banglore   New Delhi   2h 50m    non-stop
# 1           Air India   Kolkata    Banglore   7h 25m     2 stops
# 2         Jet Airways     Delhi      Cochin      19h     2 stops
# 3              IndiGo   Kolkata    Banglore   5h 25m      1 stop
# 4              IndiGo  Banglore   New Delhi   4h 45m      1 stop
# 5            SpiceJet   Kolkata    Banglore   2h 25m    non-stop
# 6         Jet Airways  Banglore   New Delhi  15h 30m      1 stop
# 7         Jet Airways  Banglore   New Delhi   21h 5m      1 stop
# 8         Jet Airways  Banglore   New Delhi  25h 30m      1 stop
# 9   Multiple carriers     Delhi      Cochin   7h 50m      1 stop
# 10          Air India     Delhi      Cochin  13h 15m      1 stop
# 11             IndiGo   Kolkata    Banglore   2h 35m    non-stop
# 12          Air India   Chennai     Kolkata   2h 15m    non-stop
# 13        Jet Airways   Kolkata    Banglore  12h 10m      1 stop
# 14             IndiGo   Kolkata    Banglore   2h 35m    non-stop
# 15          Air India     Delhi      Cochin  26h 35m     2 stops
# 16           SpiceJet     Delhi      Cochin   4h 30m      1 stop
# 17        Jet Airways     Delhi      Cochin  22h 35m      1 stop
# 18          Air India     Delhi      Cochin      23h     2 stops
# 19        Jet Airways     Delhi      Cochin  20h 35m      1 stop
# 20              GoAir     Delhi      Cochin   5h 10m      1 stop
# 21          Air India  Banglore   New Delhi  15h 20m      1 stop
# 22             IndiGo  Banglore       Delhi   2h 50m    non-stop
# 23             IndiGo  Banglore       Delhi   2h 55m    non-stop
# 24        Jet Airways   Kolkata    Banglore  13h 20m      1 stop
# 25        Jet Airways     Delhi      Cochin  15h 10m     2 stops
# 26             IndiGo     Delhi      Cochin   5h 45m      1 stop
# 27              GoAir     Delhi      Cochin   5h 55m      1 stop
# 28            Vistara  Banglore       Delhi   2h 50m    non-stop
# 29            Vistara   Chennai     Kolkata   2h 15m    non-stop
# 30            Vistara   Chennai     Kolkata   2h 15m    non-stop
# 31          Air India   Kolkata    Banglore  13h 25m     2 stops
# 32             IndiGo  Banglore       Delhi   2h 50m    non-stop
# 33        Jet Airways     Delhi      Cochin      22h     2 stops
# 34        Jet Airways     Delhi      Cochin   5h 30m      1 stop
# 35             IndiGo     Delhi      Cochin  10h 25m      1 stop
# 36           SpiceJet   Kolkata    Banglore   5h 15m      1 stop
# 37          Air India   Kolkata    Banglore   2h 30m    non-stop
# 38        Jet Airways  Banglore   New Delhi   6h 15m      1 stop
# 39        Jet Airways     Delhi      Cochin  11h 55m      1 stop
# 40  Multiple carriers     Delhi      Cochin   11h 5m      1 stop
# 41          Air India  Banglore   New Delhi   8h 30m      1 stop
# 42        Jet Airways     Delhi      Cochin   22h 5m      1 stop
# 43           Air Asia  Banglore       Delhi   2h 45m    non-stop
# 44  Multiple carriers     Delhi      Cochin      12h      1 stop
# 45           SpiceJet  Banglore   New Delhi   2h 50m    non-stop
# 46             IndiGo  Banglore       Delhi   2h 50m    non-stop
# 47          Air India   Chennai     Kolkata   2h 15m    non-stop
# 48          Air India   Kolkata    Banglore   16h 5m      1 stop
# 49        Jet Airways     Delhi      Cochin  19h 55m     2 stops
#
#                  Additional_Info  Price  Date  Month  Year  Arrival_Hour  \
# 0                        No info   3897    24      3  2019             1
# 1                        No info   7662     1      5  2019            13
# 2                        No info  13882     9      6  2019             4
# 3                        No info   6218    12      5  2019            23
# 4                        No info  13302     1      3  2019            21
# 5                        No info   3873    24      6  2019            11
# 6    In-flight meal not included  11087    12      3  2019            10
# 7                        No info  22270     1      3  2019             5
# 8    In-flight meal not included  11087    12      3  2019            10
# 9                        No info   8625    27      5  2019            19
# 10                       No info   8907     1      6  2019            23
# 11                       No info   4174    18      4  2019            22
# 12                       No info   4667    24      6  2019            13
# 13   In-flight meal not included   9663     9      5  2019             9
# 14                       No info   4804    24      4  2019            19
# 15                       No info  14011     3      3  2019            19
# 16                       No info   5830    15      4  2019            13
# 17   In-flight meal not included  10262    12      6  2019            12
# 18                       No info  13381    12      6  2019            19
# 19   In-flight meal not included  12898    27      5  2019            12
# 20                       No info  19495     6      3  2019            19
# 21                       No info   6955    21      3  2019            13
# 22                       No info   3943     3      4  2019             6
# 23                       No info   4823     1      5  2019            21
# 24   In-flight meal not included   7757     6      5  2019             8
# 25                       No info  13292     9      6  2019            12
# 26                       No info   8238     1      6  2019             3
# 27                       No info   7682    15      5  2019            12
# 28                       No info   4668    18      6  2019            12
# 29                       No info   3687    15      6  2019             9
# 30                       No info   3687    18      6  2019             9
# 31                       No info  13227     1      5  2019            23
# 32                       No info   4423     6      4  2019             6
# 33   In-flight meal not included  10919    15      6  2019            12
# 34   In-flight meal not included  12373    18      5  2019            12
# 35                       No info   5894    27      6  2019            21
# 36                       No info   4649    21      5  2019            20
# 37                       No info   6245    18      5  2019            16
# 38                       No info  19225     6      3  2019            13
# 39                       No info  14924     3      6  2019            19
# 40                       No info   9646    21      5  2019            18
# 41                       No info   8714    15      3  2019            15
# 42   In-flight meal not included  12373    18      5  2019            19
# 43                       No info   3383     6      5  2019            13
# 44                       No info  13062    21      3  2019            21
# 45  No check-in baggage included   3527    24      3  2019             8
# 46                       No info   3943    27      5  2019             6
# 47                       No info   4667     3      5  2019            13
# 48                       No info   6117    15      5  2019            11
# 49   In-flight meal not included  11150    27      6  2019            19
#
#     Arrival_Min  Dep_Hour  Dep_Min Duration_Hour Duration_Min
# 0            10        22       20             2           50
# 1            15         5       50             7           25
# 2            25         9       25            19            0
# 3            30        18        5             5           25
# 4            35        16       50             4           45
# 5            25         9        0             2           25
# 6            25        18       55            15           30
# 7             5         8        0            21            5
# 8            25         8       55            25           30
# 9            15        11       25             7           50
# 10            0         9       45            13           15
# 11           55        20       20             2           35
# 12           55        11       40             2           15
# 13           20        21       10            12           10
# 14           50        17       15             2           35
# 15           15        16       40            26           35
# 16           15         8       45             4           30
# 17           35        14        0            22           35
# 18           15        20       15            23            0
# 19           35        16        0            20           35
# 20           20        14       10             5           10
# 21           20        22        0            15           20
# 22           50         4        0             2           50
# 23           50        18       55             2           55
# 24           15        18       55            13           20
# 25           35        21       25            15           10
# 26           35        21       50             5           45
# 27           55         7        0             5           55
# 28           35         9       45             2           50
# 29           20         7        5             2           15
# 30           20         7        5             2           15
# 31           15         9       50            13           25
# 32           50         4        0             2           50
# 33           35        14       35            22            0
# 34           35         7        5             5           30
# 35            0        10       35            10           25
# 36           20        15        5             5           15
# 37           45        14       15             2           30
# 38           15         7        0             6           15
# 39            0         7        5            11           55
# 40           10         7        5            11            5
# 41           15         6       45             8           30
# 42            0        20       55            22            5
# 43           55        11       10             2           45
# 44            0         9        0            12            0
# 45           35         5       45             2           50
# 46           50         4        0             2           50
# 47           55        11       40             2           15
# 48            5        19        0            16            5
# 49            0        23        5            19           55

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Source           10683 non-null  object
#  2   Destination      10683 non-null  object
#  3   Duration         10683 non-null  object
#  4   Total_Stops      10682 non-null  object
#  5   Additional_Info  10683 non-null  object
#  6   Price            10683 non-null  int64
#  7   Date             10683 non-null  int64
#  8   Month            10683 non-null  int64
#  9   Year             10683 non-null  int64
#  10  Arrival_Hour     10683 non-null  int64
#  11  Arrival_Min      10683 non-null  int64
#  12  Dep_Hour         10683 non-null  int64
#  13  Dep_Min          10683 non-null  int64
#  14  Duration_Hour    10683 non-null  object
#  15  Duration_Min     10683 non-null  object
# dtypes: int64(8), object(8)
# memory usage: 1.3+ MB

# %%
df['Duration_Hour'].astype(int)
# df['Duration_Min'] = df['Duration_Min'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[222], line 1
# ----> 1 df['Duration_Hour'].astype(int)
#
# File ~/opt/anaconda3/envs/main1/lib/python3.10/site-packages/pandas/core/generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~/opt/anaconda3/envs/main1/lib/python3.10/site-packages/pandas/core/internals/managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
#     447 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~/opt/anaconda3/envs/main1/lib/python3.10/site-packages/pandas/core/internals/managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File ~/opt/anaconda3/envs/main1/lib/python3.10/site-packages/pandas/core/internals/blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File ~/opt/anaconda3/envs/main1/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File ~/opt/anaconda3/envs/main1/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/opt/anaconda3/envs/main1/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:170, in astype_nansafe(arr, dtype, copy, skipna)
#     166     raise ValueError(msg)
#     168 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169     # Explicit copy, or required since NumPy can't view from / to object.
# --> 170     return arr.astype(dtype, copy=True)
#     172 return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: '5m'
