# %%
from sklearn.datasets import make_classification
import pandas as pd

# %%
X,y = make_classification(n_samples=1000, n_redundant=0, n_features=2,n_clusters_per_class=1,weights=[0.90],random_state=12)

# %%
df1 = pd.DataFrame(X,columns=['feature 1','feature 2'])
df2 = pd.DataFrame(y, columns=['target'])
final_df = pd.concat([df1,df2], axis = 1)
final_df
# Out:
#      feature 1  feature 2  target
# 0    -0.762898  -0.706808       0
# 1    -1.075436  -1.051162       0
# 2    -0.610115  -0.909802       0
# 3    -2.023284  -0.428945       1
# 4    -0.812921  -1.316206       0
# ..         ...        ...     ...
# 995  -0.712495  -0.880452       0
# 996  -2.625830  -2.827891       0
# 997  -1.326439  -1.815178       0
# 998  -0.833486  -0.514647       0
# 999  -0.302876  -0.575975       0
#
# [1000 rows x 3 columns]

# %%
final_df['target'].unique()
# Out:
# array([0, 1])

# %%
final_df.groupby('target').size()
# Out:
# target
# 0    900
# 1    100
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(final_df['feature 1'], final_df['feature 2'], c = final_df['target'])

# %%
import seaborn as sns

# %%
sns.scatterplot(x=final_df['feature 1'], y=final_df['feature 2'], c = final_df['target'])
# Out:
# <Axes: xlabel='feature 1', ylabel='feature 2'>

# %%
from imblearn.over_sampling import SMOTE
oversample = SMOTE()

# %%
X,y = oversample.fit_resample(final_df[['feature 1','feature 2']], final_df['target'])

# %%
final_df.shape
# Out:
# (1000, 3)

# %%
X.shape
# Out:
# (1800, 2)

# %%
y.shape
# Out:
# (1800,)

# %%
len(final_df['target'] == 1)
# Out:
# 1000

# %%
len(y[y == 0])
# Out:
# 900

# %%
len(y[y == 1])
# Out:
# 900

# %%
len(X)
# Out:
# 1800

# %%
df1 = pd.DataFrame(X,columns=['feature 1','feature 2'])
df2 = pd.DataFrame(y, columns=['target'])
oversample_df = pd.concat([df1,df2], axis = 1)
oversample_df
# Out:
#       feature 1  feature 2  target
# 0     -0.762898  -0.706808       0
# 1     -1.075436  -1.051162       0
# 2     -0.610115  -0.909802       0
# 3     -2.023284  -0.428945       1
# 4     -0.812921  -1.316206       0
# ...         ...        ...     ...
# 1795  -1.387386   0.958401       1
# 1796  -1.910452  -0.100935       1
# 1797  -0.430266   1.163956       1
# 1798  -0.905939   0.964732       1
# 1799  -0.962833   1.432014       1
#
# [1800 rows x 3 columns]

# %%
sns.scatterplot(x=oversample_df['feature 2'], y=oversample_df['feature 1'], c = oversample_df['target'])
# Out:
# <Axes: xlabel='feature 2', ylabel='feature 1'>
